# %%
## sonarResourceCallerTCP
## simulates sonar data emitted using TCP on port 8028
## the perceiver is the qak sonarresource (project it.unibo.sonarAsResource)
import socket
import time

port = 8028
sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

msgdispatch   = "msg(sonarrobot ,dispatch,python,sonarresource,sonar(VALUE),5)"
msgevent      = "msg(sonarrobot ,event,python,none,sonar(VALUE),10)"
### alarm = "msg(alarm,event,python,none,alarm(fire),3)"

def connect(port) :
    server_address = ('192.168.1.68', port)      ##localhost
    sock.connect(server_address)    
    print("CONNECTED " , server_address)

def emit( event ) :
    print("emit ", event)
    msg = event + "\n"
    byt=msg.encode()    #required in Python3
    sock.send(byt)
    
def forward( message ) :
    print("forward ", message)
    msg = message + "\n"
    byt=msg.encode()    #required in Python3
    sock.send(byt)

def request( message ) :
    print("request ", message)
    msg = message + "\n"
    byt=msg.encode()    #required in Python3
    sock.send(byt)
    handleAnswer()

def handleAnswer() :
    print("handleAnswer " )
    while True:  ##client wants to maintain the connection
        reply = ''
        while True:
            answer = sock.recv(50)
            ## print("answer len=", len(answer))
            if len(answer) <= 0 :
                break
            reply += answer.decode("utf-8")
            ## print("reply=", reply)
            if reply.endswith("\n") :
                break
        print("final reply=", reply)
        break

def terminate() :
    sock.close()
    print("BYE")
    
def console() :  
    v =  str( input() )
    print("INPUT" , v  )    
    while( v != "q"  ) :
        ## print( v )
        emit(  msgevent.replace("VALUE", v) )
        forward(  msgdispatch.replace("VALUE", v) )
        v = str(input() )      

###########################################    
connect(port)
console()
##terminate()
# Out:
# CONNECTED  ('192.168.1.68', 8028)
# 56
# INPUT 56
# emit  msg(sonarrobot ,event,python,none,sonar(56),10)
# forward  msg(sonarrobot ,dispatch,python,sonarresource,sonar(56),5)
# q
