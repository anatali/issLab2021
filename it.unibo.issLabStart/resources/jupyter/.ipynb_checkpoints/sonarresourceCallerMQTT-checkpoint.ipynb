# %%
## sonarresourceCallerMQTT
## simulates sonar data emitted using MQTT
## the perceiver is the qak sonarresource (project it.unibo.sonarAsResource)
import time
import paho.mqtt.client as paho
 
brokerAddr     = "192.168.1.45"   ##"broker.hivemq.com"
topic          = "sonar/data"
 
msgdispatch   = "msg(applupdate ,dispatch,python,sonarresource,applupdate(VALUE),5)"
msgevent      = "msg(sonarrobot ,event,python,sonarresource,sonar(VALUE),10)"

def sendMqtt( message ) :
    print("sendMqtt ", message)
    msg = message + "\n"
    #byt=msg.encode()    #required in Python3
    client.publish(topic, msg)

def on_message(client, userdata, message) :
    print("message received " ,str(message.payload.decode("utf-8")))
    ## print("message topic=",message.topic)
    ## print("message qos=",message.qos)
    ## print("message retain flag=",message.retain)
    

def init() :
    client.subscribe(topic, qos=0)      #subscribe before publish
    client.on_message=on_message        #attach function to callback
    client.loop_start()  #check for input messages

def terminate() :
    client.disconnect()
    print("BYE")
    
def console() :  
    v =  str( input() )
    print("INPUT" , v  )    
    while( v != "q"  ) :
        ## print( v )
        m = msgdispatch.replace("VALUE",v)
        print( "sending:"+m)
        sendMqtt( m )
        v = str(input() )    
        
#################################################   
client= paho.Client("senderPython")      
client.connect(brokerAddr)              #connect
print("connected to broker ", brokerAddr)
init()
console()
print("BYE")
##terminate()
# Out:
# connected to broker  192.168.1.45
# 45
# INPUT 45
# sending:msg(sonarrobot ,dispatch,python,sonarresource,sonar(45),5)
# sendMqtt  msg(sonarrobot ,dispatch,python,sonarresource,sonar(45),5)
# message received  msg(sonarrobot ,dispatch,python,sonarresource,sonar(45),5)
#
# 45
# sending:msg(sonarrobot ,dispatch,python,sonarresource,sonar(45),5)
# sendMqtt  msg(sonarrobot ,dispatch,python,sonarresource,sonar(45),5)
# message received  msg(sonarrobot ,dispatch,python,sonarresource,sonar(45),5)
#
# message received  msg(sonarrobot,event,sendermock,none,sonar(50),8)
# 44
# sending:msg(sonarrobot ,dispatch,python,sonarresource,sonar(44),5)
# sendMqtt  msg(sonarrobot ,dispatch,python,sonarresource,sonar(44),5)
# message received  msg(sonarrobot ,dispatch,python,sonarresource,sonar(44),5)
#
# 66
# sending:msg(sonarrobot ,dispatch,python,sonarresource,sonar(66),5)
# sendMqtt  msg(sonarrobot ,dispatch,python,sonarresource,sonar(66),5)
# message received  msg(sonarrobot ,dispatch,python,sonarresource,sonar(66),5)
#
# 77
# sending:msg(sonarrobot ,dispatch,python,sonarresource,sonar(77),5)
# sendMqtt  msg(sonarrobot ,dispatch,python,sonarresource,sonar(77),5)
# message received  msg(sonarrobot ,dispatch,python,sonarresource,sonar(77),5)
#
# 22
# sending:msg(sonarrobot ,dispatch,python,sonarresource,sonar(22),5)
# sendMqtt  msg(sonarrobot ,dispatch,python,sonarresource,sonar(22),5)
# message received  msg(sonarrobot ,dispatch,python,sonarresource,sonar(22),5)
#
# message received  msg(sonarrobot,event,sonar,none,sonar(80),11)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),14)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),16)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),18)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),20)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),22)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),24)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),26)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),28)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),30)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),32)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),34)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),36)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),38)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),40)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),42)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),44)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),46)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),48)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),50)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),52)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),54)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),56)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),58)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),60)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),62)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),64)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),66)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),68)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),70)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),72)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),74)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),76)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),78)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),80)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),82)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),84)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),86)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),88)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),90)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),92)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),94)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),96)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),98)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),100)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),102)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),104)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),106)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),108)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),110)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),112)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),114)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),116)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),118)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),120)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),122)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),124)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),126)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),128)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),130)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),132)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),134)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),136)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),138)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),140)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),142)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),144)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),146)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),148)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),150)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),152)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),154)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),156)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),158)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),160)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),162)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),164)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),166)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),168)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),170)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),172)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),174)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),176)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),178)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),180)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),182)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),184)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),186)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),188)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),190)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),192)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),194)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),196)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),198)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),200)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),202)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),204)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),206)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),208)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),210)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),212)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),214)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),216)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),218)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),220)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),222)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),224)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),226)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),228)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),230)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),232)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),234)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),236)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),238)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),240)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),242)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),244)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),246)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),248)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),250)
# message received  msg(sonarrobot,event,sonar,none,sonar(36),252)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),254)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),256)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),258)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),260)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),262)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),264)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),266)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),268)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),270)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),272)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),274)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),276)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),278)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),280)
# message received  msg(sonarrobot,event,sonar,none,sonar(36),282)
# message received  msg(sonarrobot,event,sonar,none,sonar(44),284)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),286)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),288)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),290)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),292)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),294)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),296)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),298)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),300)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),302)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),304)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),306)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),308)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),310)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),312)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),314)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),316)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),318)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),320)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),322)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),324)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),326)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),328)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),330)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),332)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),334)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),336)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),338)
# message received  msg(sonarrobot,event,sonar,none,sonar(38),340)
# message received  msg(sonarrobot,event,sonar,none,sonar(40),342)
# message received  msg(sonarrobot,event,sonar,none,sonar(40),344)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),346)
# message received  msg(sonarrobot,event,sonar,none,sonar(36),348)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),350)
# message received  msg(sonarrobot,event,sonar,none,sonar(56),352)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),354)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),356)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),358)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),360)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),362)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),364)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),366)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),368)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),370)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),372)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),374)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),376)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),378)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),380)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),382)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),384)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),386)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),388)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),390)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),392)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),394)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),396)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),398)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),400)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),402)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),404)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),406)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),408)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),410)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),412)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),414)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),416)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),418)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),420)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),422)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),424)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),426)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),428)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),430)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),432)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),434)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),436)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),438)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),440)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),442)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),444)
# message received  msg(sonarrobot,event,sonar,none,sonar(6),446)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),448)
# message received  msg(sonarrobot,event,sonar,none,sonar(6),450)
# message received  msg(sonarrobot,event,sonar,none,sonar(6),452)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),454)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),456)
# message received  msg(sonarrobot,event,sonar,none,sonar(6),458)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),460)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),462)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),464)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),466)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),468)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),470)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),472)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),474)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),476)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),478)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),480)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),482)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),484)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),486)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),488)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),490)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),492)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),494)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),496)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),498)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),500)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),502)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),504)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),506)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),508)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),510)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),512)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),514)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),516)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),518)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),520)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),522)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),524)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),526)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),528)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),530)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),532)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),534)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),536)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),538)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),540)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),542)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),544)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),546)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),548)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),550)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),552)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),554)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),556)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),558)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),560)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),562)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),564)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),566)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),568)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),570)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),572)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),574)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),576)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),578)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),580)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),582)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),584)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),586)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),588)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),590)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),592)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),594)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),596)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),598)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),600)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),602)
# message received  msg(sonarrobot,event,sonar,none,sonar(74),604)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),606)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),608)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),610)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),612)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),614)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),616)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),618)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),620)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),622)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),624)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),626)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),628)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),630)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),632)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),634)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),636)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),638)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),640)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),642)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),644)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),646)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),648)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),650)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),652)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),654)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),656)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),658)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),660)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),662)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),664)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),666)
# message received  msg(sonarrobot,event,sonar,none,sonar(76),668)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),670)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),672)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),674)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),676)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),678)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),680)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),682)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),684)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),686)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),688)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),690)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),692)
# message received  msg(sonarrobot,event,sonar,none,sonar(82),694)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),697)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),699)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),701)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),703)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),705)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),707)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),709)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),711)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),713)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),715)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),717)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),719)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),721)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),723)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),725)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),727)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),729)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),731)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),733)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),735)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),737)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),739)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),741)
# message received  msg(sonarrobot,event,sonar,none,sonar(78),743)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),745)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),747)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),749)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),751)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),11)
# message received  msg(sonarrobot,event,sonar,none,sonar(70),13)
# message received  msg(sonarrobot,event,sonar,none,sonar(60),15)
# message received  msg(sonarrobot,event,sonar,none,sonar(50),17)
# message received  msg(sonarrobot,event,sonar,none,sonar(40),19)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),21)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),23)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),25)
# message received  msg(sonarrobot,event,sendermock,none,sonar(50),8)
# message received  msg(sonarrobot,event,sonar,none,sonar(80),11)
# message received  msg(sonarrobot,event,sonar,none,sonar(70),13)
# message received  msg(sonarrobot,event,sonar,none,sonar(60),15)
# message received  msg(sonarrobot,event,sonar,none,sonar(50),17)
# message received  msg(sonarrobot,event,sonar,none,sonar(40),19)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),21)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),23)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),25)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),11)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),14)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),16)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),18)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),20)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),22)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),24)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),26)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),28)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),30)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),32)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),34)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),36)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),38)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),40)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),42)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),44)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),46)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),48)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),50)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),52)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),54)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),56)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),58)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),60)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),62)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),64)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),66)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),68)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),70)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),72)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),74)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),76)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),78)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),80)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),82)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),84)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),86)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),88)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),90)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),92)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),94)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),96)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),98)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),100)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),102)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),104)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),106)
# message received  msg(sonarrobot,event,sonar,none,sonar(90),108)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),110)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),112)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),114)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),116)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),118)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),120)
# message received  msg(sonarrobot,event,sonar,none,sonar(90),122)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),124)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),126)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),128)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),130)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),132)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),134)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),136)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),138)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),140)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),142)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),144)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),146)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),148)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),150)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),152)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),154)
# message received  msg(sonarrobot,event,sonar,none,sonar(90),156)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),158)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),160)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),162)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),164)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),166)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),168)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),170)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),172)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),174)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),176)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),178)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),180)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),182)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),184)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),186)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),188)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),190)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),192)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),194)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),196)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),198)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),200)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),202)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),204)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),206)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),208)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),210)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),212)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),214)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),216)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),218)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),220)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),222)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),224)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),226)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),228)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),230)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),232)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),234)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),236)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),238)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),240)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),242)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),244)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),246)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),248)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),250)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),252)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),254)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),256)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),258)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),260)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),262)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),264)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),266)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),268)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),270)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),272)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),274)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),276)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),278)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),280)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),282)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),284)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),286)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),288)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),290)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),292)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),294)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),296)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),298)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),300)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),302)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),304)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),306)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),308)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),310)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),312)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),314)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),316)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),318)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),320)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),322)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),324)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),326)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),328)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),330)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),332)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),334)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),336)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),338)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),340)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),342)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),344)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),346)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),348)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),350)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),352)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),354)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),356)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),358)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),360)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),362)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),364)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),366)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),368)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),370)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),372)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),374)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),376)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),378)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),380)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),382)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),384)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),386)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),388)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),390)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),392)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),394)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),396)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),398)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),400)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),402)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),404)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),406)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),408)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),410)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),412)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),414)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),416)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),418)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),420)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),422)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),424)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),426)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),428)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),430)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),432)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),434)
# message received  msg(sonarrobot,event,sonar,none,sonar(40),436)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),438)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),440)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),442)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),444)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),446)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),448)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),450)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),452)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),454)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),456)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),458)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),460)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),462)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),464)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),466)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),468)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),470)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),472)
# message received  msg(sonarrobot,event,sonar,none,sonar(8),474)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),476)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),478)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),480)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),482)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),484)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),486)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),488)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),490)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),492)
# message received  msg(sonarrobot,event,sonar,none,sonar(36),494)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),496)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),498)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),500)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),502)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),504)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),506)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),508)
# message received  msg(sonarrobot,event,sonar,none,sonar(36),510)
# message received  msg(sonarrobot,event,sonar,none,sonar(36),512)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),514)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),516)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),518)
# message received  msg(sonarrobot,event,sonar,none,sonar(36),520)
# message received  msg(sonarrobot,event,sonar,none,sonar(36),522)
# message received  msg(sonarrobot,event,sonar,none,sonar(38),524)
# message received  msg(sonarrobot,event,sonar,none,sonar(38),526)
# message received  msg(sonarrobot,event,sonar,none,sonar(38),528)
# message received  msg(sonarrobot,event,sonar,none,sonar(38),530)
# message received  msg(sonarrobot,event,sonar,none,sonar(38),532)
# message received  msg(sonarrobot,event,sonar,none,sonar(38),534)
# message received  msg(sonarrobot,event,sonar,none,sonar(38),536)
# message received  msg(sonarrobot,event,sonar,none,sonar(36),538)
# message received  msg(sonarrobot,event,sonar,none,sonar(36),540)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),542)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),544)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),546)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),548)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),550)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),552)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),554)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),556)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),558)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),560)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),562)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),564)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),566)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),568)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),570)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),572)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),574)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),576)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),578)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),580)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),582)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),584)
# message received  msg(sonarrobot,event,sonar,none,sonar(14),586)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),588)
# message received  msg(sonarrobot,event,sonar,none,sonar(10),590)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),592)
# message received  msg(sonarrobot,event,sonar,none,sonar(12),594)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),596)
# message received  msg(sonarrobot,event,sonar,none,sonar(16),598)
# message received  msg(sonarrobot,event,sonar,none,sonar(62),600)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),602)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),604)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),606)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),608)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),610)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),612)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),614)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),616)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),618)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),620)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),622)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),624)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),626)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),628)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),630)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),632)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),634)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),636)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),638)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),640)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),642)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),644)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),646)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),648)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),650)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),652)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),654)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),656)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),658)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),660)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),662)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),664)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),666)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),668)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),670)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),672)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),674)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),676)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),678)
# message received  msg(sonarrobot,event,sonar,none,sonar(84),680)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),682)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),684)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),686)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),688)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),690)
# message received  msg(sonarrobot,event,sonar,none,sonar(36),692)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),694)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),696)
# message received  msg(sonarrobot,event,sonar,none,sonar(32),698)
# message received  msg(sonarrobot,event,sonar,none,sonar(36),700)
# message received  msg(sonarrobot,event,sonar,none,sonar(34),702)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),704)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),706)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),708)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),710)
# message received  msg(sonarrobot,event,sonar,none,sonar(30),712)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),714)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),716)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),718)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),720)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),722)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),724)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),726)
# message received  msg(sonarrobot,event,sonar,none,sonar(28),728)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),730)
# message received  msg(sonarrobot,event,sonar,none,sonar(24),732)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),734)
# message received  msg(sonarrobot,event,sonar,none,sonar(22),736)
# message received  msg(sonarrobot,event,sonar,none,sonar(18),738)
# message received  msg(sonarrobot,event,sonar,none,sonar(20),740)
# message received  msg(sonarrobot,event,sonar,none,sonar(26),742)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),744)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),746)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),748)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),750)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),752)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),754)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),756)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),758)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),760)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),762)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),764)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),766)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),768)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),770)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),772)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),774)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),776)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),778)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),780)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),782)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),784)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),786)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),788)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),790)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),792)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),794)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),796)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),798)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),800)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),802)
# message received  msg(sonarrobot,event,sonar,none,sonar(86),804)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),806)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),808)
# message received  msg(sonarrobot,event,sonar,none,sonar(88),810)
