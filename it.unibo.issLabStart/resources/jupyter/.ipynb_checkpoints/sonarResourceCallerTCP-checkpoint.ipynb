# %%
## sonarResourceCallerTCP
## simulates sonar data emitted using TCP on port 8028
## the perceiver is the qak sonarresource (project it.unibo.sonarAsResource)
import socket
import time

port = 8028
sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

msgdispatch   = "msg(applupdate ,dispatch,python,sonarresource,applupdate(VALUE),5)"
msgevent      = "msg(sonarrobot ,event,   python,none,         sonar(VALUE),10)"
### alarm = "msg(alarm,event,python,none,alarm(fire),3)"

def connect(port) :
    server_address = ('192.168.1.48', port)      ##localhost
    sock.connect(server_address)    
    print("CONNECTED " , server_address)

def emit( event ) :
    print("emit ", event)
    msg = event + "\n"
    byt=msg.encode()    #required in Python3
    sock.send(byt)
    
def forward( message ) :
    print("forward ", message)
    msg = message + "\n"
    byt=msg.encode()    #required in Python3
    sock.send(byt)

def request( message ) :
    print("request ", message)
    msg = message + "\n"
    byt=msg.encode()    #required in Python3
    sock.send(byt)
    handleAnswer()

def handleAnswer() :
    print("handleAnswer " )
    while True:  ##client wants to maintain the connection
        reply = ''
        while True:
            answer = sock.recv(50)
            ## print("answer len=", len(answer))
            if len(answer) <= 0 :
                break
            reply += answer.decode("utf-8")
            ## print("reply=", reply)
            if reply.endswith("\n") :
                break
        print("final reply=", reply)
        break

def terminate() :
    sock.close()
    print("BYE")
    
def console() :  
    v =  str( input() )
    print("INPUT" , v  )    
    while( v != "q"  ) :
        ## print( v )
        emit(  msgevent.replace("VALUE", v) )
        ## forward(  msgdispatch.replace("VALUE", v) )
        v = str(input() )      

###########################################    
connect(port)
console()
##terminate()
# Out:
# CONNECTED  ('192.168.1.48', 8028)
# 34
# INPUT 34
# emit  msg(sonarrobot ,event,python,none,sonar(34),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(34),5)
# 12
# emit  msg(sonarrobot ,event,python,none,sonar(12),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(12),5)
# 15
# emit  msg(sonarrobot ,event,python,none,sonar(15),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(15),5)
# 60
# emit  msg(sonarrobot ,event,python,none,sonar(60),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(60),5)
# 12
# emit  msg(sonarrobot ,event,python,none,sonar(12),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(12),5)
# 50
# emit  msg(sonarrobot ,event,python,none,sonar(50),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(50),5)
# 22
# emit  msg(sonarrobot ,event,python,none,sonar(22),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(22),5)
# 50
# emit  msg(sonarrobot ,event,python,none,sonar(50),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(50),5)
# 80
# emit  msg(sonarrobot ,event,python,none,sonar(80),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(80),5)
# 43
# emit  msg(sonarrobot ,event,python,none,sonar(43),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(43),5)
# 20
# emit  msg(sonarrobot ,event,python,none,sonar(20),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(20),5)
# 50
# emit  msg(sonarrobot ,event,python,none,sonar(50),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(50),5)
# 51
# emit  msg(sonarrobot ,event,python,none,sonar(51),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(51),5)
# 52
# emit  msg(sonarrobot ,event,python,none,sonar(52),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(52),5)
# 53
# emit  msg(sonarrobot ,event,python,none,sonar(53),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(53),5)
# 54
# emit  msg(sonarrobot ,event,python,none,sonar(54),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(54),5)
# 12
# emit  msg(sonarrobot ,event,python,none,sonar(12),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(12),5)
# 35
# emit  msg(sonarrobot ,event,python,none,sonar(35),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(35),5)
# 50
# emit  msg(sonarrobot ,event,python,none,sonar(50),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(50),5)
# 12
# emit  msg(sonarrobot ,event,python,none,sonar(12),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(12),5)
# 60
# emit  msg(sonarrobot ,event,python,none,sonar(60),10)
# forward  msg(applupdate ,dispatch,python,sonarresource,applupdate(60),5)
# q
